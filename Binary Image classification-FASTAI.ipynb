# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2                #This automatically reloads the modules and upgrades them on usage
# %matplotlib inline          
#makes matplot lib runs at back end with the set[by user] default features

# %%
import os
from fastai.imports import *

# %%
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.backends.cudnn.enabled
# Out:
# True

# %%
os.getcwd()
os.chdir('C:\\Users\\avinash_l01\\Downloads\\Google Images')
os.getcwd()
# Out:
# 'C:\\Users\\avinash_l01\\Downloads\\Google Images'

# %%
#lets see the data
os.listdir()
# Out:
# ['airtel images',
#  'idea images',
#  'jio images',
#  'models',
#  'test',
#  'tmp',
#  'train',
#  'valid',
#  'vodafone images']

# %%
img=plt.imread('train/Airtel/10.jpg')
plt.imshow(img)

# %%
#shape of image
img.shape
# Out:
# (360, 640, 3)

# %% [markdown]
# # Model Build

# %%
path='C:\\Users\\avinash_l01\\Downloads\\Google Images'
arch=vgg16
sz=224
data=ImageClassifierData.from_paths(path=path,tfms=tfms_from_model(arch,sz))
learn=ConvLearner.pretrained(arch,data=data,precompute=True)
#learn.fit(0.1,1)     --can't run from the local machine will hung up!!
# Out:
#   0%|                                                    | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-1a944eb02fea> in <module>()
#       3 sz=224
#       4 data=ImageClassifierData.from_paths(path=path,tfms=tfms_from_model(arch,sz))
# ----> 5 learn=ConvLearner.pretrained(arch,data=data,precompute=True)
#       6 learn.fit(0.1,1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\fastai-0.7.0-py3.6.egg\fastai\conv_learner.py in pretrained(cls, f, data, ps, xtra_fc, xtra_cut, custom_head, precompute, pretrained, **kwargs)
#     112         models = ConvnetBuilder(f, data.c, data.is_multi, data.is_reg,
#     113             ps=ps, xtra_fc=xtra_fc, xtra_cut=xtra_cut, custom_head=custom_head, pretrained=pretrained)
# --> 114         return cls(data, models, precompute, **kwargs)
#     115
#     116     @classmethod
#
# ...

# %%
data.val_y
# Out:
# array([0, 1])

# %%
data.classes
#this says 0 for Airtel & 1 for Idea
# Out:
# ['Airtel', 'Idea']

# %%
learn.
